# %% [markdown]
# Objective for Exercise: Learn some advance functionality of ipynb, load a built-in dataset and explore it.

# %%
# Installing 3rd party libraries

# %%
# !pip  install Pandas Scikit-learn Numpy h5py Cython Flask Seaborn Scipy Numpy Matplotlib Ipython Jupyter Sympy Nose
# Out:
# Requirement already satisfied: Pandas in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: Scikit-learn in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (0.24.2)
# Requirement already satisfied: Numpy in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.20.3)
# Requirement already satisfied: h5py in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (3.2.1)
# Requirement already satisfied: Cython in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (0.29.24)
# Requirement already satisfied: Flask in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.1.2)
# Requirement already satisfied: Seaborn in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: Scipy in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.7.1)
# Requirement already satisfied: Matplotlib in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: Ipython in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (7.29.0)
# Requirement already satisfied: Jupyter in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: Sympy in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.9)
# Requirement already satisfied: Nose in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (1.3.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Pandas) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Scikit-learn) (2.2.0)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Flask) (2.0.1)
# Requirement already satisfied: click>=5.1 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Flask) (8.0.3)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Flask) (2.0.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Matplotlib) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (0.7.5)
# Requirement already satisfied: decorator in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (5.1.0)
# Requirement already satisfied: pygments in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (2.10.0)
# Requirement already satisfied: backcall in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (4.8.0)
# Requirement already satisfied: appnope in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Ipython) (58.0.4)
# Requirement already satisfied: nbconvert in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jupyter) (6.1.0)
# Requirement already satisfied: ipykernel in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jupyter) (6.4.1)
# Requirement already satisfied: jupyter-console in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jupyter) (6.4.0)
# Requirement already satisfied: qtconsole in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jupyter) (5.1.1)
# Requirement already satisfied: notebook in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jupyter) (6.4.5)
# Requirement already satisfied: ipywidgets in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jupyter) (7.6.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Sympy) (1.2.1)
# Requirement already satisfied: six in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->Matplotlib) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->Ipython) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask) (1.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->Ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython) (0.2.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->Jupyter) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->Jupyter) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->Jupyter) (1.4.1)
# Requirement already satisfied: ipython-genutils in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->Jupyter) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->Jupyter) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel->Jupyter) (22.2.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->Jupyter) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->Jupyter) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets->Jupyter) (5.1.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets->Jupyter) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->Jupyter) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->Jupyter) (0.18.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from notebook->Jupyter) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from notebook->Jupyter) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from notebook->Jupyter) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from notebook->Jupyter) (0.11.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook->Jupyter) (1.14.6)
# Requirement already satisfied: pycparser in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->Jupyter) (2.20)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (0.3)
# Requirement already satisfied: testpath in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (0.1.2)
# Requirement already satisfied: defusedxml in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (0.5.3)
# Requirement already satisfied: bleach in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->Jupyter) (4.0.0)
# Requirement already satisfied: nest-asyncio in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->Jupyter) (1.5.1)
# Requirement already satisfied: async-generator in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->Jupyter) (1.10)
# Requirement already satisfied: webencodings in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->Jupyter) (0.5.1)
# Requirement already satisfied: packaging in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->Jupyter) (21.0)
# Requirement already satisfied: qtpy in /Users/iaquine/opt/anaconda3/lib/python3.9/site-packages (from qtconsole->Jupyter) (1.10.0)

# %%
#Loading a data set which comes with “Seaborn”

# %%
import seaborn

iris = seaborn.load_dataset("iris")
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
iris['species'].unique() #finding out categories
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.groupby('species').count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
seaborn.pairplot(iris, hue="species", palette='icefire')
#This gives us a lot of information for a single line of code. 
First, we see the data distributions per column and species on the diagonal. Then we see all pair-wise scatter plots on the remaining tiles, again broken down by color. It is, for example, obvious to see that a line can be drawn to separate “setosa” against “versicolor” and “virginica”. In later courses, we’ll of course teach how the overlapping species can be separated as well. This is called supervised machine learning using non-linear classifiers by the way.
